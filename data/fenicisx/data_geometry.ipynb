# %%
import gmsh
import numpy as np
from mpi4py import MPI
from dolfinx.io import XDMFFile, gmshio
from dolfinx.io.gmshio import read_from_msh

# %%
def draw_mesh(r1, r2, angle):
    gmsh.initialize()
    gmsh.clear()
    gmsh.model.add("test")
    gmsh.model.setCurrent("test")

    gmsh.model.occ.addPoint(250e-3,0,0,meshSize=10e-3, tag=1)
    gmsh.model.occ.addPoint(250e-3, 500e-3, 0, meshSize=10e-3, tag=2)
    gmsh.model.occ.addPoint(0,0,0,meshSize=10e-3, tag=3)
    gmsh.model.occ.addPoint(0,500e-3,0, meshSize=10e-3, tag=4)

    gmsh.model.occ.addLine(3,1,tag=1)
    gmsh.model.occ.addLine(3,4,tag=2)
    gmsh.model.occ.addLine(1,2,tag=3)
    gmsh.model.occ.addLine(2,4,tag=4)

    gmsh.model.occ.addCurveLoop([3,4,-2,1], tag=1)


    
    gmsh.model.occ.addPoint(80e-3+r1, 150e-3, 0, meshSize=4e-3, tag=20)   
    gmsh.model.occ.addEllipse(80e-3,150e-3,0, r1,r2, tag=5, angle1=0, angle2=2*np.pi,) 
    gmsh.model.occ.rotate([(0,20),(1,5)],80e-3,150e-3,0,0,0,1,angle/180*np.pi)
    gmsh.model.occ.addCurveLoop([5], tag=2)

    gmsh.model.occ.addPoint(170e-3+r1, 150e-3, 0, meshSize=4e-3, tag=22)
    gmsh.model.occ.addEllipse(170e-3,150e-3,0, r1,r2, tag=6, angle1=0, angle2=2*np.pi,)
    gmsh.model.occ.rotate([(0,22),(1,6)],170e-3,150e-3,0,0,0,1,angle/180*np.pi)
    gmsh.model.occ.addCurveLoop([6], tag=3)

    gmsh.model.occ.addPoint(80e-3+r1, 250e-3, 0, meshSize=4e-3, tag=24)
    gmsh.model.occ.addEllipse(80e-3,250e-3,0, r1,r2, tag=7, angle1=0, angle2=2*np.pi,)
    gmsh.model.occ.rotate([(0,24),(1,7)],80e-3,250e-3,0,0,0,1,angle/180*np.pi)
    gmsh.model.occ.addCurveLoop([7], tag=4)

    
    gmsh.model.occ.addPoint(170e-3+r1, 250e-3, 0, meshSize=4e-3, tag=26)
    gmsh.model.occ.addEllipse(170e-3,250e-3,0, r1,r2, tag=8, angle1=0, angle2=2*np.pi,)
    gmsh.model.occ.rotate([(0,26),(1,8)],170e-3,250e-3,0,0,0,1,angle/180*np.pi)
    gmsh.model.occ.addCurveLoop([8], tag=5)

    gmsh.model.occ.addPoint(80e-3+r1, 350e-3, 0, meshSize=4e-3, tag=28)
    gmsh.model.occ.addEllipse(80e-3,350e-3,0, r1,r2, tag=9, angle1=0, angle2=2*np.pi,)
    gmsh.model.occ.rotate([(0,28),(1,9)],80e-3,350e-3,0,0,0,1,angle/180*np.pi)
    gmsh.model.occ.addCurveLoop([9], tag=6)

    gmsh.model.occ.addPoint(170e-3+r1, 350e-3, 0, meshSize=4e-3, tag=30)
    gmsh.model.occ.addEllipse(170e-3,350e-3,0, r1,r2, tag=10, angle1=0, angle2=2*np.pi,)
    gmsh.model.occ.rotate([(0,30),(1,10)],170e-3,350e-3,0,0,0,1,angle/180*np.pi)
    gmsh.model.occ.addCurveLoop([10], tag=7)


    gmsh.model.occ.addPlaneSurface([1,2,3,4,5,6,7], tag=1)


    gmsh.model.occ.synchronize()

    gmsh.model.addPhysicalGroup(1, [1], 1, "fixed")
    gmsh.model.addPhysicalGroup(1, [4], 2, "load")
    gmsh.model.addPhysicalGroup(1, [2,3,5,6,7,8,9,10], 3, "free")
    gmsh.model.addPhysicalGroup(2, [1], 4, "domain")

    gmsh.model.mesh.generate(2)
    gmsh.model.mesh.optimize("Netgen")

    model_rank = 0
    mesh_comm = MPI.COMM_WORLD
    domain, ct, ft = gmshio.model_to_mesh(gmsh.model, mesh_comm, model_rank, gdim=2)
    gmsh.finalize()
    return domain

# %%
"""
import pyvista
from dolfinx.plot import vtk_mesh

domain, ct=draw_mesh(40e-3, 10e-3, 30)
pyvista.start_xvfb()
plotter = pyvista.Plotter()
tdim = domain.topology.dim
domain.topology.create_connectivity(tdim, tdim)
grid = pyvista.UnstructuredGrid(*vtk_mesh(domain, tdim))
num_local_cells = domain.topology.index_map(tdim).size_local
grid.cell_data["Marker"] = ct.values[ct.indices < num_local_cells]
grid.set_active_scalars("Marker")
actor = plotter.add_mesh(grid, show_edges=True, color="white")
plotter.view_xy()

plotter.show()
"""
# Out:
# '\nimport pyvista\nfrom dolfinx.plot import vtk_mesh\n\ndomain, ct=draw_mesh(40e-3, 10e-3, 30)\npyvista.start_xvfb()\nplotter = pyvista.Plotter()\ntdim = domain.topology.dim\ndomain.topology.create_connectivity(tdim, tdim)\ngrid = pyvista.UnstructuredGrid(*vtk_mesh(domain, tdim))\nnum_local_cells = domain.topology.index_map(tdim).size_local\ngrid.cell_data["Marker"] = ct.values[ct.indices < num_local_cells]\ngrid.set_active_scalars("Marker")\nactor = plotter.add_mesh(grid, show_edges=True, color="white")\nplotter.view_xy()\n\nplotter.show()\n'

# %%
import os
from dolfinx import mesh, fem, plot, io, default_scalar_type
from dolfinx.fem.petsc import LinearProblem
from mpi4py import MPI
import ufl
import numpy as np
from dolfinx import geometry




def epsilon(u):
    return ufl.sym(ufl.grad(u))  # Equivalent to 0.5*(ufl.nabla_grad(u) + ufl.nabla_grad(u).T)


def sigma(u):
    return lambda_ * ufl.nabla_div(u) * ufl.Identity(len(u)) + 2 * mu * epsilon(u)



if not os.path.exists("data_geometry"):
    os.makedirs("data_geometry")

N=1000
r1=25e-3+(15e-3)*np.random.rand(1000)
r2=((25e-3)**2)/r1
theta=90*np.ones(1000)
angle=np.zeros(1000)
for n in range(N):
    
    
    domain=draw_mesh(r1[n],r2[n], angle[n])
    E = fem.Constant(domain, 210e9)
    nu = fem.Constant(domain, 0.3)

    lmbda = E * nu / (1 + nu) / (1 - 2 * nu)
    mu = E / 2 / (1 + nu)

    beta = 1.25
    lambda_ = beta

    V = fem.functionspace(domain, ("Lagrange", 1, (domain.geometry.dim, )))

    def clamped_boundary(x):
        return np.isclose(x[1], 0)


    fdim = domain.topology.dim - 1
    boundary_facets = mesh.locate_entities_boundary(domain, fdim, clamped_boundary)

    u_D = np.array([0, 0], dtype=default_scalar_type)
    bc = fem.dirichletbc(u_D, fem.locate_dofs_topological(V, fdim, boundary_facets), V)

    boundaries = [(1, lambda x: np.isclose(x[0], 0)),
                (2, lambda x: np.isclose(x[0], 250e-3)),
                (3, lambda x: np.isclose(x[1], 500e-3))]

    facet_indices, facet_markers = [], []
    fdim = domain.topology.dim - 1
    for (marker, locator) in boundaries:
        facets = mesh.locate_entities(domain, fdim, locator)
        facet_indices.append(facets)
        facet_markers.append(np.full_like(facets, marker))
    facet_indices = np.hstack(facet_indices).astype(np.int32)
    facet_markers = np.hstack(facet_markers).astype(np.int32)
    sorted_facets = np.argsort(facet_indices)
    facet_tag = mesh.meshtags(domain, fdim, facet_indices[sorted_facets], facet_markers[sorted_facets])
    ds = ufl.Measure("ds", domain=domain, subdomain_data=facet_tag)
    T0 = fem.Constant(domain, default_scalar_type((0, 0)))
    T1 = fem.Constant(domain, default_scalar_type((100e6*np.cos(theta[n]*np.pi/180), 100e6*np.sin(theta[n]*np.pi/180))))
    u = ufl.TrialFunction(V)
    v = ufl.TestFunction(V)
    f = fem.Constant(domain, default_scalar_type((0, 0)))
    a = ufl.inner(sigma(u), epsilon(v)) * ufl.dx
    L = ufl.dot(f, v) * ufl.dx + ufl.dot(T0, v) * ds(1) + ufl.dot(T0, v) * ds(2) + + ufl.dot(T1, v) * ds(3)
    problem = LinearProblem(a, L, bcs=[bc], petsc_options={"ksp_type": "preonly", "pc_type": "lu"})
    uh = problem.solve()
    
    s = sigma(uh) - 1. / 3 * ufl.tr(sigma(uh)) * ufl.Identity(len(uh))
    von_Mises = ufl.sqrt(3. / 2 * ufl.inner(s, s))

    V_von_mises = fem.functionspace(domain, ("DG", 0))
    stress_expr = fem.Expression(von_Mises, V_von_mises.element.interpolation_points())
    stresses = fem.Function(V_von_mises)
    stresses.interpolate(stress_expr)

    cell_to_vertices = domain.topology.connectivity(domain.topology.dim, 0).array.reshape(-1,3)
    points= domain.geometry.x.reshape(-1,3)

    bb_tree = geometry.bb_tree(domain, domain.topology.dim)
    cells = []
    points_on_proc = []
    # Find cells whose bounding-box collide with the the points
    cell_candidates = geometry.compute_collisions_points(bb_tree, points)
    # Choose one of the cells that contains the point
    colliding_cells = geometry.compute_colliding_cells(domain, cell_candidates, points)
    for i, point in enumerate(points):
        if len(colliding_cells.links(i)) > 0:
            points_on_proc.append(point)
            cells.append(colliding_cells.links(i)[0])
    val=stresses.eval(domain.geometry.x, cells)

        
    if not os.path.exists("data_geometry/"+str(n)):
        os.makedirs("data_geometry/"+str(n))
    np.save("data_geometry/"+str(n)+"/H_holes.npy", np.array([[80e-3,150e-3, r1[n],r2[n],angle[n]],[170e-3,150e-3,r1[n],r2[n],angle[n]],[80e-3, 250e-3, r1[n],r2[n],angle[n]],[170e-3, 250e-3, r1[n],r2[n],angle[n]],[80e-3, 350e-3, r1[n],r2[n],angle[n]],[170e-3, 350e-3, r1[n],r2[n],angle[n]]]))
    np.save("data_geometry/"+str(n)+"/H_angle.npy", np.array([theta[n]]))
    np.save("data_geometry/"+str(n)+"/H_mesh_geometry.npy", points[:,:2])
    np.save("data_geometry/"+str(n)+"/H_mesh_topology.npy", cell_to_vertices)
    np.save("data_geometry/"+str(n)+"/H_y.npy", val)
# Out:
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0219615s, CPU 0.022412s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.138653s, CPU 0.138155s)
# Info    : 4108 nodes 8230 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.1e-06s, CPU 0s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.033731s, CPU 0.033184s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.140524s, CPU 0.140234s)
# Info    : 4038 nodes 8090 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 3e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0309112s, CPU 0.031198s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.136106s, CPU 0.136169s)
# Info    : 4019 nodes 8052 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0158331s, CPU 0.016213s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.1352s, CPU 0.134826s)
# Info    : 4065 nodes 8144 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.1e-06s, CPU 1e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0311057s, CPU 0.031439s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.134918s, CPU 0.134964s)
# Info    : 4008 nodes 8030 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 4e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0296687s, CPU 0.029983s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.136156s, CPU 0.136185s)
# Info    : 4058 nodes 8130 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.3e-06s, CPU 3e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0196795s, CPU 0.011946s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.134312s, CPU 0.133735s)
# Info    : 4000 nodes 8014 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 1e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0098345s, CPU 0.010123s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.135018s, CPU 0.13506s)
# Info    : 4069 nodes 8152 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.1e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.01896s, CPU 0.019267s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.134613s, CPU 0.134645s)
# Info    : 4020 nodes 8054 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.7e-06s, CPU 3e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0345563s, CPU 0.034936s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.138674s, CPU 0.138703s)
# Info    : 4054 nodes 8122 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.4e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.019468s, CPU 0.019769s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.13487s, CPU 0.134937s)
# Info    : 4001 nodes 8016 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0345352s, CPU 0.034899s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.145524s, CPU 0.14557s)
# Info    : 4068 nodes 8150 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0190724s, CPU 0.019303s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.132576s, CPU 0.132605s)
# Info    : 4012 nodes 8038 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0315311s, CPU 0.031801s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.13848s, CPU 0.138516s)
# Info    : 4086 nodes 8186 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0304347s, CPU 0.030738s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.135071s, CPU 0.135193s)
# Info    : 4011 nodes 8036 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0281577s, CPU 0.028486s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.138218s, CPU 0.13825s)
# Info    : 4092 nodes 8198 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.4e-06s, CPU 3e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0268291s, CPU 0.02711s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.135789s, CPU 0.135833s)
# Info    : 4006 nodes 8026 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 3e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0313037s, CPU 0.031547s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.135221s, CPU 0.134896s)
# Info    : 4003 nodes 8020 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.7e-06s, CPU 4e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0186505s, CPU 0.0189s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.138729s, CPU 0.138771s)
# Info    : 4065 nodes 8144 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 3e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0322609s, CPU 0.032619s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.138191s, CPU 0.138141s)
# Info    : 4055 nodes 8124 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0148866s, CPU 0.015169s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.133805s, CPU 0.133833s)
# Info    : 4049 nodes 8112 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 1e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0194413s, CPU 0.019726s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.134643s, CPU 0.134677s)
# Info    : 3980 nodes 7974 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 3e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0341605s, CPU 0.034291s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.142263s, CPU 0.1423s)
# Info    : 4075 nodes 8164 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0344933s, CPU 0.034799s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.142955s, CPU 0.142999s)
# Info    : 4056 nodes 8126 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 3e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0193714s, CPU 0.019685s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.134008s, CPU 0.134036s)
# Info    : 4020 nodes 8054 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0237306s, CPU 0.023789s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.136178s, CPU 0.136229s)
# Info    : 4039 nodes 8092 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0348454s, CPU 0.025985s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.141943s, CPU 0.141846s)
# Info    : 4056 nodes 8126 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.3e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0311146s, CPU 0.031321s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.139881s, CPU 0.139905s)
# Info    : 4135 nodes 8284 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.3e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0278767s, CPU 0.0282s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.133285s, CPU 0.133314s)
# Info    : 3992 nodes 7998 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.028034s, CPU 0.028364s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.137293s, CPU 0.137336s)
# Info    : 4105 nodes 8224 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0323348s, CPU 0.032491s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.137799s, CPU 0.137847s)
# Info    : 4012 nodes 8038 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.1e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.018907s, CPU 0.019196s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.132445s, CPU 0.132472s)
# Info    : 4038 nodes 8090 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0193555s, CPU 0.019646s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.134137s, CPU 0.13417s)
# Info    : 4018 nodes 8050 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0296981s, CPU 0.030024s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.137394s, CPU 0.137446s)
# Info    : 4090 nodes 8194 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0284588s, CPU 0.028785s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.136879s, CPU 0.136919s)
# Info    : 4109 nodes 8232 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0317619s, CPU 0.032128s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.138077s, CPU 0.138106s)
# Info    : 4068 nodes 8150 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 1e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0221928s, CPU 0.022467s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.135867s, CPU 0.135912s)
# Info    : 4087 nodes 8188 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.1e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0335635s, CPU 0.03388s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.138194s, CPU 0.138121s)
# Info    : 4036 nodes 8086 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.1e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0167831s, CPU 0.017068s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.132791s, CPU 0.13282s)
# Info    : 4044 nodes 8102 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.9e-06s, CPU 3e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0288817s, CPU 0.029152s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.136561s, CPU 0.136607s)
# Info    : 4082 nodes 8178 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.7e-06s, CPU 3e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0318816s, CPU 0.032199s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.137804s, CPU 0.137838s)
# Info    : 4074 nodes 8162 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.1e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0342486s, CPU 0.034538s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.146388s, CPU 0.146419s)
# Info    : 4101 nodes 8216 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.3e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0184393s, CPU 0.018731s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.134528s, CPU 0.134571s)
# Info    : 4056 nodes 8126 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 3e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0335074s, CPU 0.033816s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.137537s, CPU 0.137587s)
# Info    : 4059 nodes 8132 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.1e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0337006s, CPU 0.033821s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.141805s, CPU 0.141768s)
# Info    : 4110 nodes 8234 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.3e-06s, CPU 3e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0147059s, CPU 0.015015s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.133716s, CPU 0.133745s)
# Info    : 4063 nodes 8140 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.7e-06s, CPU 3e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0192689s, CPU 0.019555s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.133152s, CPU 0.133194s)
# Info    : 4015 nodes 8044 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 3e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0194922s, CPU 0.01977s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.133921s, CPU 0.133792s)
# Info    : 4004 nodes 8022 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.1e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0329883s, CPU 0.033257s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.139878s, CPU 0.139904s)
# Info    : 4106 nodes 8226 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0342737s, CPU 0.034548s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.139481s, CPU 0.139516s)
# Info    : 4052 nodes 8118 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0304477s, CPU 0.030711s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.136626s, CPU 0.136675s)
# Info    : 4031 nodes 8076 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0302095s, CPU 0.030588s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.13545s, CPU 0.135382s)
# Info    : 4016 nodes 8046 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.4e-06s, CPU 3e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0219561s, CPU 0.022235s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.138978s, CPU 0.139009s)
# Info    : 4116 nodes 8246 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.1e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0302032s, CPU 0.030473s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.13629s, CPU 0.136101s)
# Info    : 4016 nodes 8046 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 3e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0335446s, CPU 0.033895s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.140919s, CPU 0.140964s)
# Info    : 4059 nodes 8132 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.1e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0308047s, CPU 0.031106s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.136692s, CPU 0.136724s)
# Info    : 4015 nodes 8044 elements
# Info    : Optimizing mesh (Netgen)...
# ...
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.018699s, CPU 0.01902s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.144817s, CPU 0.145211s)
# Info    : 4045 nodes 8104 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 4e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0328857s, CPU 0.033257s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.142126s, CPU 0.142534s)
# Info    : 4120 nodes 8254 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0268693s, CPU 0.026987s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.1357s, CPU 0.136116s)
# Info    : 4012 nodes 8038 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0341136s, CPU 0.034438s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.152193s, CPU 0.152605s)
# Info    : 4065 nodes 8144 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.1e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0304578s, CPU 0.030739s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.138696s, CPU 0.139099s)
# Info    : 4007 nodes 8028 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.034265s, CPU 0.034459s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.14541s, CPU 0.136164s)
# Info    : 4135 nodes 8284 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0187494s, CPU 0.019038s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.134849s, CPU 0.135233s)
# Info    : 4028 nodes 8070 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.7e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0237275s, CPU 0.024015s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.135775s, CPU 0.136165s)
# Info    : 4048 nodes 8110 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0225504s, CPU 0.022837s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.137094s, CPU 0.137486s)
# Info    : 4068 nodes 8150 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.1e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0304256s, CPU 0.030717s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.143384s, CPU 0.143796s)
# Info    : 4017 nodes 8048 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 1e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0323889s, CPU 0.032682s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.139078s, CPU 0.139485s)
# Info    : 4051 nodes 8116 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.3e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0287858s, CPU 0.029058s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.139826s, CPU 0.140239s)
# Info    : 4084 nodes 8182 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.023803s, CPU 0.024139s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.139439s, CPU 0.139868s)
# Info    : 4041 nodes 8096 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.7e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0236194s, CPU 0.01425s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.135627s, CPU 0.135892s)
# Info    : 4025 nodes 8064 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0335898s, CPU 0.033865s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.143297s, CPU 0.143698s)
# Info    : 4065 nodes 8144 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.028843s, CPU 0.02916s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.143545s, CPU 0.143945s)
# Info    : 4088 nodes 8190 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.3e-06s, CPU 3e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0230895s, CPU 0.023369s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.137497s, CPU 0.137942s)
# Info    : 4080 nodes 8174 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.1e-06s, CPU 4e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0262101s, CPU 0.026517s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.142975s, CPU 0.143381s)
# Info    : 4026 nodes 8066 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0340567s, CPU 0.034286s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.142452s, CPU 0.142794s)
# Info    : 4073 nodes 8160 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)

# %%
#x,y=np.meshgrid(np.array([0,2,4]),np.array([1,3,5,7,9]))
#x.reshape(-1).reshape(5,3)

# %%
#import matplotlib.pyplot as plt
#plt.contourf(x, y, final_val.reshape(500,250), 800)

# %%
def draw_mesh(r1, r2,angle):
    gmsh.initialize()
    gmsh.clear()
    gmsh.model.add("test")
    gmsh.model.setCurrent("test")

    gmsh.model.occ.addPoint(250e-3,0,0,meshSize=40e-3, tag=1)
    gmsh.model.occ.addPoint(250e-3, 500e-3, 0, meshSize=40e-3, tag=2)
    gmsh.model.occ.addPoint(0,0,0,meshSize=40e-3, tag=3)
    gmsh.model.occ.addPoint(0,500e-3,0, meshSize=40e-3, tag=4)

    gmsh.model.occ.addLine(3,1,tag=1)
    gmsh.model.occ.addLine(3,4,tag=2)
    gmsh.model.occ.addLine(1,2,tag=3)
    gmsh.model.occ.addLine(2,4,tag=4)

    gmsh.model.occ.addCurveLoop([3,4,-2,1], tag=1)


    
    gmsh.model.occ.addPoint(80e-3+r1, 150e-3, 0, meshSize=16e-3, tag=20)   
    gmsh.model.occ.addEllipse(80e-3,150e-3,0, r1,r2, tag=5, angle1=0, angle2=2*np.pi,) 
    gmsh.model.occ.rotate([(0,20),(1,5)],80e-3,150e-3,0,0,0,1,angle/180*np.pi)
    gmsh.model.occ.addCurveLoop([5], tag=2)

    gmsh.model.occ.addPoint(170e-3+r1, 150e-3, 0, meshSize=16e-3, tag=22)
    gmsh.model.occ.addEllipse(170e-3,150e-3,0, r1,r2, tag=6, angle1=0, angle2=2*np.pi,)
    gmsh.model.occ.rotate([(0,22),(1,6)],170e-3,150e-3,0,0,0,1,angle/180*np.pi)
    gmsh.model.occ.addCurveLoop([6], tag=3)

    gmsh.model.occ.addPoint(80e-3+r1, 250e-3, 0, meshSize=16e-3, tag=24)
    gmsh.model.occ.addEllipse(80e-3,250e-3,0, r1,r2, tag=7, angle1=0, angle2=2*np.pi,)
    gmsh.model.occ.rotate([(0,24),(1,7)],80e-3,250e-3,0,0,0,1,angle/180*np.pi)
    gmsh.model.occ.addCurveLoop([7], tag=4)

    
    gmsh.model.occ.addPoint(170e-3+r1, 250e-3, 0, meshSize=16e-3, tag=26)
    gmsh.model.occ.addEllipse(170e-3,250e-3,0, r1,r2, tag=8, angle1=0, angle2=2*np.pi,)
    gmsh.model.occ.rotate([(0,26),(1,8)],170e-3,250e-3,0,0,0,1,angle/180*np.pi)
    gmsh.model.occ.addCurveLoop([8], tag=5)

    gmsh.model.occ.addPoint(80e-3+r1, 350e-3, 0, meshSize=16e-3, tag=28)
    gmsh.model.occ.addEllipse(80e-3,350e-3,0, r1,r2, tag=9, angle1=0, angle2=2*np.pi,)
    gmsh.model.occ.rotate([(0,28),(1,9)],80e-3,350e-3,0,0,0,1,angle/180*np.pi)
    gmsh.model.occ.addCurveLoop([9], tag=6)

    gmsh.model.occ.addPoint(170e-3+r1, 350e-3, 0, meshSize=16e-3, tag=30)
    gmsh.model.occ.addEllipse(170e-3,350e-3,0, r1,r2, tag=10, angle1=0, angle2=2*np.pi,)
    gmsh.model.occ.rotate([(0,30),(1,10)],170e-3,350e-3,0,0,0,1,angle/180*np.pi)
    gmsh.model.occ.addCurveLoop([10], tag=7)


    gmsh.model.occ.addPlaneSurface([1,2,3,4,5,6,7], tag=1)


    gmsh.model.occ.synchronize()

    gmsh.model.addPhysicalGroup(1, [1], 1, "fixed")
    gmsh.model.addPhysicalGroup(1, [4], 2, "load")
    gmsh.model.addPhysicalGroup(1, [2,3,5,6,7,8,9,10], 3, "free")
    gmsh.model.addPhysicalGroup(2, [1], 4, "domain")

    gmsh.model.mesh.generate(2)
    gmsh.model.mesh.optimize("Netgen")

    model_rank = 0
    mesh_comm = MPI.COMM_WORLD
    domain, ct, ft = gmshio.model_to_mesh(gmsh.model, mesh_comm, model_rank, gdim=2)
    gmsh.finalize()
    return domain

# %%
"""
pyvista.start_xvfb()
plotter = pyvista.Plotter()
tdim = domain.topology.dim
domain.topology.create_connectivity(tdim, tdim)
grid = pyvista.UnstructuredGrid(*vtk_mesh(domain, tdim))
num_local_cells = domain.topology.index_map(tdim).size_local
grid.cell_data["Marker"] = ct.values[ct.indices < num_local_cells]
grid.set_active_scalars("Marker")
actor = plotter.add_mesh(grid, show_edges=True, color="white")
plotter.view_xy()

plotter.show()
"""
# Out:
# '\npyvista.start_xvfb()\nplotter = pyvista.Plotter()\ntdim = domain.topology.dim\ndomain.topology.create_connectivity(tdim, tdim)\ngrid = pyvista.UnstructuredGrid(*vtk_mesh(domain, tdim))\nnum_local_cells = domain.topology.index_map(tdim).size_local\ngrid.cell_data["Marker"] = ct.values[ct.indices < num_local_cells]\ngrid.set_active_scalars("Marker")\nactor = plotter.add_mesh(grid, show_edges=True, color="white")\nplotter.view_xy()\n\nplotter.show()\n'

# %%
def epsilon(u):
    return ufl.sym(ufl.grad(u))  # Equivalent to 0.5*(ufl.nabla_grad(u) + ufl.nabla_grad(u).T)


def sigma(u):
    return lambda_ * ufl.nabla_div(u) * ufl.Identity(len(u)) + 2 * mu * epsilon(u)



if not os.path.exists("data_geometry"):
    os.makedirs("data_geometry")


for n in range(N):
    domain=draw_mesh(r1[n],r2[n], angle[n])
    E = fem.Constant(domain, 210e9)
    nu = fem.Constant(domain, 0.3)

    lmbda = E * nu / (1 + nu) / (1 - 2 * nu)
    mu = E / 2 / (1 + nu)

    beta = 1.25
    lambda_ = beta

    V = fem.functionspace(domain, ("Lagrange", 1, (domain.geometry.dim, )))

    def clamped_boundary(x):
        return np.isclose(x[1], 0)


    fdim = domain.topology.dim - 1
    boundary_facets = mesh.locate_entities_boundary(domain, fdim, clamped_boundary)

    u_D = np.array([0, 0], dtype=default_scalar_type)
    bc = fem.dirichletbc(u_D, fem.locate_dofs_topological(V, fdim, boundary_facets), V)

    boundaries = [(1, lambda x: np.isclose(x[0], 0)),
                (2, lambda x: np.isclose(x[0], 250e-3)),
                (3, lambda x: np.isclose(x[1], 500e-3))]

    facet_indices, facet_markers = [], []
    fdim = domain.topology.dim - 1
    for (marker, locator) in boundaries:
        facets = mesh.locate_entities(domain, fdim, locator)
        facet_indices.append(facets)
        facet_markers.append(np.full_like(facets, marker))
    facet_indices = np.hstack(facet_indices).astype(np.int32)
    facet_markers = np.hstack(facet_markers).astype(np.int32)
    sorted_facets = np.argsort(facet_indices)
    facet_tag = mesh.meshtags(domain, fdim, facet_indices[sorted_facets], facet_markers[sorted_facets])
    ds = ufl.Measure("ds", domain=domain, subdomain_data=facet_tag)
    
    
    
    T0 = fem.Constant(domain, default_scalar_type((0, 0)))
    T1 = fem.Constant(domain, default_scalar_type((100e6*np.cos(theta[n]*np.pi/180), 100e6*np.sin(theta[n]*np.pi/180))))
    u = ufl.TrialFunction(V)
    v = ufl.TestFunction(V)
    f = fem.Constant(domain, default_scalar_type((0, 0)))
    a = ufl.inner(sigma(u), epsilon(v)) * ufl.dx
    L = ufl.dot(f, v) * ufl.dx + ufl.dot(T0, v) * ds(1) + ufl.dot(T0, v) * ds(2) + + ufl.dot(T1, v) * ds(3)
    problem = LinearProblem(a, L, bcs=[bc], petsc_options={"ksp_type": "preonly", "pc_type": "lu"})
    uh = problem.solve()
    
    s = sigma(uh) - 1. / 3 * ufl.tr(sigma(uh)) * ufl.Identity(len(uh))
    von_Mises = ufl.sqrt(3. / 2 * ufl.inner(s, s))

    V_von_mises = fem.functionspace(domain, ("DG", 0))
    stress_expr = fem.Expression(von_Mises, V_von_mises.element.interpolation_points())
    stresses = fem.Function(V_von_mises)
    stresses.interpolate(stress_expr)

    cell_to_vertices = domain.topology.connectivity(domain.topology.dim, 0).array.reshape(-1,3)
    points= domain.geometry.x.reshape(-1,3)

    bb_tree = geometry.bb_tree(domain, domain.topology.dim)
    cells = []
    points_on_proc = []
    # Find cells whose bounding-box collide with the the points
    cell_candidates = geometry.compute_collisions_points(bb_tree, points)
    # Choose one of the cells that contains the point
    colliding_cells = geometry.compute_colliding_cells(domain, cell_candidates, points)
    for i, point in enumerate(points):
        if len(colliding_cells.links(i)) > 0:
            points_on_proc.append(point)
            cells.append(colliding_cells.links(i)[0])
    val=stresses.eval(domain.geometry.x, cells)

    
    
    if not os.path.exists("data_geometry/"+str(n)):
        os.makedirs("data_geometry/"+str(n))
    np.save("data_geometry/"+str(n)+"/L_holes.npy", np.array([[80e-3,150e-3, r1[n],r2[n],angle[n]],[170e-3,150e-3,r1[n],r2[n],angle[n]],[80e-3, 250e-3, r1[n],r2[n],angle[n]],[170e-3, 250e-3, r1[n],r2[n],angle[n]],[80e-3, 350e-3, r1[n],r2[n],angle[n]],[170e-3, 350e-3, r1[n],r2[n],angle[n]]]))
    np.save("data_geometry/"+str(n)+"/L_angle.npy", np.array([theta[n]]))
    np.save("data_geometry/"+str(n)+"/L_mesh_geometry.npy", points[:,:2])
    np.save("data_geometry/"+str(n)+"/L_mesh_topology.npy", cell_to_vertices)
    np.save("data_geometry/"+str(n)+"/L_y.npy", val)
# Out:
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0174239s, CPU 0.017773s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0279976s, CPU 0.028513s)
# Info    : 336 nodes 686 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0198289s, CPU 0.018405s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0247011s, CPU 0.024656s)
# Info    : 346 nodes 706 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 1e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0189659s, CPU 0.019259s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0245999s, CPU 0.024631s)
# Info    : 361 nodes 736 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.1e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0095274s, CPU 0.009768s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0240434s, CPU 0.024072s)
# Info    : 357 nodes 728 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0188944s, CPU 0.013846s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0247731s, CPU 0.024702s)
# Info    : 362 nodes 738 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0184304s, CPU 0.018708s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0242322s, CPU 0.024277s)
# Info    : 366 nodes 746 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0161545s, CPU 0.016747s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0235319s, CPU 0.023569s)
# Info    : 349 nodes 712 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.1e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0069888s, CPU 0.007185s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0237102s, CPU 0.023738s)
# Info    : 358 nodes 730 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0120227s, CPU 0.012292s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0232259s, CPU 0.023197s)
# Info    : 347 nodes 708 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0195079s, CPU 0.019764s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.024026s, CPU 0.024432s)
# Info    : 343 nodes 700 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0147349s, CPU 0.014989s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0239682s, CPU 0.024369s)
# Info    : 345 nodes 704 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.7e-06s, CPU 3e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0207159s, CPU 0.020953s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0256657s, CPU 0.025695s)
# Info    : 379 nodes 772 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.1e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0137202s, CPU 0.011346s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0240415s, CPU 0.024075s)
# Info    : 357 nodes 728 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.1e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0190355s, CPU 0.019319s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0244614s, CPU 0.024857s)
# Info    : 360 nodes 734 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0187644s, CPU 0.019033s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0248562s, CPU 0.024885s)
# Info    : 363 nodes 740 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.1e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0181093s, CPU 0.015603s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0245093s, CPU 0.02443s)
# Info    : 369 nodes 752 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0187259s, CPU 0.014484s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0247234s, CPU 0.024985s)
# Info    : 376 nodes 766 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.3e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0191247s, CPU 0.019394s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0249091s, CPU 0.024937s)
# Info    : 361 nodes 736 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.1e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.010621s, CPU 0.010945s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0238899s, CPU 0.02392s)
# Info    : 358 nodes 730 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0192365s, CPU 0.019948s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0242284s, CPU 0.024259s)
# Info    : 350 nodes 714 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0094757s, CPU 0.007694s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0245565s, CPU 0.024475s)
# Info    : 360 nodes 734 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0162839s, CPU 0.016544s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0234986s, CPU 0.023534s)
# Info    : 342 nodes 698 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.6e-06s, CPU 3e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0207116s, CPU 0.02137s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0266243s, CPU 0.026745s)
# Info    : 383 nodes 780 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.6e-06s, CPU 3e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0215871s, CPU 0.022244s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0251973s, CPU 0.025246s)
# Info    : 381 nodes 776 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.3e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.014929s, CPU 0.015227s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0235326s, CPU 0.023558s)
# Info    : 347 nodes 708 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0176116s, CPU 0.017881s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0257384s, CPU 0.02612s)
# Info    : 382 nodes 778 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.1e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0207013s, CPU 0.021425s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.025582s, CPU 0.025624s)
# Info    : 380 nodes 774 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 1e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0191903s, CPU 0.019447s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0250778s, CPU 0.02513s)
# Info    : 361 nodes 736 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0181287s, CPU 0.018375s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0249537s, CPU 0.025401s)
# Info    : 374 nodes 762 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.1e-06s, CPU 1e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0182183s, CPU 0.018805s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0245981s, CPU 0.024587s)
# Info    : 364 nodes 742 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.1e-06s, CPU 1e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0195751s, CPU 0.019851s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0248793s, CPU 0.024921s)
# Info    : 356 nodes 726 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.3e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.012099s, CPU 0.012308s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.022992s, CPU 0.022952s)
# Info    : 346 nodes 706 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.1e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0147941s, CPU 0.015587s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0239751s, CPU 0.024005s)
# Info    : 348 nodes 710 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0183765s, CPU 0.016714s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0256259s, CPU 0.025521s)
# Info    : 370 nodes 754 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 1e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0181646s, CPU 0.018422s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0244215s, CPU 0.024456s)
# Info    : 362 nodes 738 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.7e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0193187s, CPU 0.010789s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0248898s, CPU 0.02495s)
# Info    : 354 nodes 722 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.8e-06s, CPU 3e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0169659s, CPU 0.017232s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0248411s, CPU 0.024843s)
# Info    : 381 nodes 776 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0195367s, CPU 0.019804s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0238688s, CPU 0.023919s)
# Info    : 340 nodes 694 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.3e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0098398s, CPU 0.010575s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0245461s, CPU 0.024906s)
# Info    : 360 nodes 734 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.1e-06s, CPU 1e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0186246s, CPU 0.018907s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0254609s, CPU 0.025489s)
# Info    : 370 nodes 754 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.3e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0197019s, CPU 0.019252s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0247743s, CPU 0.024803s)
# Info    : 360 nodes 734 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0213439s, CPU 0.022072s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.02587s, CPU 0.026262s)
# Info    : 379 nodes 772 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0106489s, CPU 0.010898s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0238201s, CPU 0.023844s)
# Info    : 353 nodes 720 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.3e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0194092s, CPU 0.019651s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0237985s, CPU 0.023829s)
# Info    : 340 nodes 694 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.01983s, CPU 0.020641s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0258663s, CPU 0.0259s)
# Info    : 384 nodes 782 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0095229s, CPU 0.009778s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0240387s, CPU 0.024017s)
# Info    : 358 nodes 730 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.1e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0152198s, CPU 0.015311s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.023982s, CPU 0.024022s)
# Info    : 342 nodes 698 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.3e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0157663s, CPU 0.013311s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0239273s, CPU 0.024245s)
# Info    : 345 nodes 704 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0193346s, CPU 0.020046s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0246789s, CPU 0.024698s)
# Info    : 349 nodes 712 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.5e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0209337s, CPU 0.021183s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0257048s, CPU 0.025776s)
# Info    : 380 nodes 774 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0188041s, CPU 0.019067s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0246529s, CPU 0.025106s)
# Info    : 362 nodes 738 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.1e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0176448s, CPU 0.018322s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0250764s, CPU 0.025082s)
# Info    : 380 nodes 774 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.1e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.016935s, CPU 0.017202s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0248702s, CPU 0.024903s)
# Info    : 378 nodes 770 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0185297s, CPU 0.018801s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0245012s, CPU 0.024531s)
# Info    : 360 nodes 734 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.5e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.019571s, CPU 0.018677s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0237788s, CPU 0.023717s)
# Info    : 341 nodes 696 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 1e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0188327s, CPU 0.019108s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0244176s, CPU 0.02445s)
# Info    : 362 nodes 738 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# ...
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0112447s, CPU 0.011909s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0243224s, CPU 0.024352s)
# Info    : 359 nodes 732 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.1e-06s, CPU 1e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0212315s, CPU 0.021616s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0245519s, CPU 0.014873s)
# Info    : 356 nodes 726 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.1e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0180115s, CPU 0.018278s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.024621s, CPU 0.02465s)
# Info    : 374 nodes 762 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.1e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0207203s, CPU 0.021417s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0259931s, CPU 0.026045s)
# Info    : 383 nodes 780 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0186697s, CPU 0.017207s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.024784s, CPU 0.024645s)
# Info    : 365 nodes 744 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.1e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0211535s, CPU 0.021424s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0253442s, CPU 0.025368s)
# Info    : 370 nodes 754 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.1e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0119426s, CPU 0.012217s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0297345s, CPU 0.029767s)
# Info    : 354 nodes 722 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.1e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0178247s, CPU 0.018124s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0250277s, CPU 0.025056s)
# Info    : 378 nodes 770 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.1e-06s, CPU 1e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0176024s, CPU 0.017917s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0250814s, CPU 0.025079s)
# Info    : 380 nodes 774 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.4e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0190254s, CPU 0.019431s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0245773s, CPU 0.024625s)
# Info    : 362 nodes 738 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 1e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0193481s, CPU 0.01963s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0243767s, CPU 0.024402s)
# Info    : 356 nodes 726 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.1e-06s, CPU 1e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0182555s, CPU 0.018517s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0251064s, CPU 0.025133s)
# Info    : 367 nodes 748 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0178157s, CPU 0.018104s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0247358s, CPU 0.024792s)
# Info    : 376 nodes 766 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.1e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0176738s, CPU 0.017919s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0248207s, CPU 0.024772s)
# Info    : 379 nodes 772 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.1e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0193492s, CPU 0.019617s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0242032s, CPU 0.024102s)
# Info    : 348 nodes 710 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.1e-06s, CPU 1e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.022156s, CPU 0.022432s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0256931s, CPU 0.025635s)
# Info    : 365 nodes 744 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0173881s, CPU 0.011877s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.024647s, CPU 0.024675s)
# Info    : 381 nodes 776 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.2e-06s, CPU 2e-06s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0178738s, CPU 0.018134s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0243381s, CPU 0.024352s)
# Info    : 376 nodes 766 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1.3e-06s, CPU 0s)
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Ellipse)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Ellipse)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : [100%] Meshing curve 10 (Ellipse)
# Info    : Done meshing 1D (Wall 0.020791s, CPU 0.020012s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.026632s, CPU 0.026674s)
# Info    : 386 nodes 786 elements
# Info    : Optimizing mesh (Netgen)...
# Info    : Done optimizing mesh (Wall 1e-06s, CPU 2e-06s)

# %%
"""
pyvista.start_xvfb()

# Create plotter and pyvista grid
p = pyvista.Plotter()
topology, cell_types, geo = plot.vtk_mesh(V)
grid = pyvista.UnstructuredGrid(topology, cell_types, geo)

# Attach vector values to grid and warp grid by vector
grid["VonMises"] = stresses.x.array
grid.set_active_scalars("VonMises")
p.add_mesh(grid, show_edges=False)

p.show_axes()

p.show()
"""
# Out:
# '\npyvista.start_xvfb()\n\n# Create plotter and pyvista grid\np = pyvista.Plotter()\ntopology, cell_types, geo = plot.vtk_mesh(V)\ngrid = pyvista.UnstructuredGrid(topology, cell_types, geo)\n\n# Attach vector values to grid and warp grid by vector\ngrid["VonMises"] = stresses.x.array\ngrid.set_active_scalars("VonMises")\np.add_mesh(grid, show_edges=False)\n\np.show_axes()\n\np.show()\n'
